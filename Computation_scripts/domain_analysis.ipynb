# %%
import typing as t
import operator as op
import subprocess as sp
import glob
import os
from concurrent.futures import ThreadPoolExecutor, ProcessPoolExecutor
from itertools import chain

import tqdm
import pandas as pd
from fn import F
from Bio import SearchIO, SeqIO

pd.set_option('display.max_rows', 1000)
# %matplotlib inline

# %%
#!pip3 install tqdm
# Out:
# Collecting tqdm
#   Downloading tqdm-4.43.0-py2.py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 1.6 MB/s eta 0:00:011
# Installing collected packages: tqdm
# Successfully installed tqdm-4.43.0

# %%
#!pip3 install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.0.1-cp37-cp37m-manylinux1_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 3.9 MB/s eta 0:00:01    |▏                               | 40 kB 3.0 MB/s eta 0:00:04
# Collecting numpy>=1.13.3
#   Downloading numpy-1.18.1-cp37-cp37m-manylinux1_x86_64.whl (20.1 MB)
#      |████████████████████████████████| 20.1 MB 6.2 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.6.1 in ./.conda/envs/cellulase_project/lib/python3.7/site-packages (from pandas) (2.8.1)
# Collecting pytz>=2017.2
#   Downloading pytz-2019.3-py2.py3-none-any.whl (509 kB)
#      |████████████████████████████████| 509 kB 7.0 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.5 in ./.conda/envs/cellulase_project/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas) (1.14.0)
# Installing collected packages: numpy, pytz, pandas
# Successfully installed numpy-1.18.1 pandas-1.0.1 pytz-2019.3

# %%
#!pip3 install fn
# Out:
# Collecting fn
#   Downloading fn-0.4.3.tar.gz (38 kB)
# Building wheels for collected packages: fn
#   Building wheel for fn (setup.py) ... done
#   Created wheel for fn: filename=fn-0.4.3-py3-none-any.whl size=28473 sha256=e91ac167f87d0f446ff280a5ec8026e21a1edad60ee031f81af77d91c6b7e903
#   Stored in directory: /home/is6/.cache/pip/wheels/5c/a0/65/41f733d04386c57826c2cf9e1927d716e90a46689712c9af6b
# Successfully built fn
# Installing collected packages: fn
# Successfully installed fn-0.4.3

# %%
#!pip3 install biopython
# Out:
# Collecting biopython
#   Downloading biopython-1.76-cp37-cp37m-manylinux1_x86_64.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 4.5 MB/s eta 0:00:01
# Requirement already satisfied: numpy in ./.conda/envs/cellulase_project/lib/python3.7/site-packages (from biopython) (1.18.1)
# Installing collected packages: biopython
# Successfully installed biopython-1.76

# %%
#!pip3 install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.2.0-cp37-cp37m-manylinux1_x86_64.whl (12.4 MB)
#      |████████████████████████████████| 12.4 MB 6.7 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.1 in ./.conda/envs/cellulase_project/lib/python3.7/site-packages (from matplotlib) (2.8.1)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.1.0-cp37-cp37m-manylinux1_x86_64.whl (90 kB)
#      |████████████████████████████████| 90 kB 4.3 MB/s eta 0:00:011
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1
#   Downloading pyparsing-2.4.6-py2.py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 2.3 MB/s eta 0:00:011
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: numpy>=1.11 in ./.conda/envs/cellulase_project/lib/python3.7/site-packages (from matplotlib) (1.18.1)
# Requirement already satisfied: six>=1.5 in ./.conda/envs/cellulase_project/lib/python3.7/site-packages (from python-dateutil>=2.1->matplotlib) (1.14.0)
# Requirement already satisfied: setuptools in ./.conda/envs/cellulase_project/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib) (45.2.0.post20200210)
# Installing collected packages: kiwisolver, pyparsing, cycler, matplotlib
# Successfully installed cycler-0.10.0 kiwisolver-1.1.0 matplotlib-3.2.0 pyparsing-2.4.6

# %%
# all modules have been installed

# %% [markdown]
# Parse hmmscan output and extract domain annotations

# %%
scan_files = [
    'hmmscan/sp.txt',
    'hmmscan/chz.txt'
]
samples = ['sp', 'chz']

scans = [
    list(SearchIO.parse(fname, 'hmmer3-text')) for fname in scan_files
]

# %%
hmmscan_annotation_keys = [
    'query', 'model', 'description', 'bitscore', 
    'evalue', 'domains_expected', 'domains_observed'
]

def extract_query_annotations(query) -> pd.DataFrame:
    query_id = query.id
    hits = query.hits
    hit_ids = [hit.id for hit in hits]
    hit_descriptions = [hit.description for hit in hits]
    hit_scores = [hit.bitscore for hit in hits]
    hit_evalues = [hit.evalue for hit in hits]
    domains_expected = [hit.domain_exp_num for hit in hits]
    domains_observed = [hit.domain_obs_num for hit in hits]
    records = [
        [query_id, hit_id, hit_descr, hit_score, hit_eval, dom_exp, dom_obs]
        for hit_id, hit_descr, hit_score, hit_eval, dom_exp, dom_obs, in 
        zip(hit_ids, hit_descriptions, hit_scores, hit_evalues,
            domains_expected, domains_observed)
    ]
    return pd.DataFrame(records, columns=hmmscan_annotation_keys)


def extract_hmmscan_annotations(sample_id, sample_queries) -> pd.DataFrame:
    empty = pd.DataFrame(
        data=[['NA', 'NA', 'NA', 0, 99999.0, 0.0, 0.0]], 
        columns=hmmscan_annotation_keys
    )
    hmmscan = (
        F(map, extract_query_annotations)
        >> list
        >> (lambda dfs: pd.concat(dfs) if dfs else empty)
        >> (lambda df: df.reset_index(drop=True))
    )(sample_queries)
    return pd.concat([
        pd.Series(sample_id, index=hmmscan.index, name='sample'),
        hmmscan
    ], axis=1)

# %%
scan_annotations = [
    extract_hmmscan_annotations(id_, scan) for id_, scan in zip(samples, scans)
]

# %%
scan_annotations_concat = (
    pd.concat(scan_annotations)
    .reset_index(drop=True)
    .sort_values(['sample', 'description'])
)
scan_annotations_concat.head()
# Out:
#     sample           query       model  \
# 122    chz  NFBJIBDF_18870  PF06964.12
# 134    chz  NFBJIBDF_33696  PF06964.12
# 138    chz  NFBJIBDF_36526  PF06964.12
# 144    chz  NFBJIBDF_42607  PF06964.12
# 155    chz  NFBJIBDF_49966  PF06964.12
#
#                                        description  bitscore        evalue  \
# 122  Alpha-L-arabinofuranosidase C-terminal domain     142.6  1.500000e-44
# 134  Alpha-L-arabinofuranosidase C-terminal domain     139.1  1.900000e-43
# 138  Alpha-L-arabinofuranosidase C-terminal domain      99.0  4.000000e-31
# 144  Alpha-L-arabinofuranosidase C-terminal domain     131.8  3.300000e-41
# 155  Alpha-L-arabinofuranosidase C-terminal domain      98.1  7.500000e-31
#
#      domains_expected domains_observed
# 122               1.3                1
# 134               1.8                2
# 138               1.4                1
# 144               1.2                1
# 155               1.0                1

# %%
#scan_annotations_concat.tail()
# Out:
#     sample           query       model  \
# 294    chz  NFBJIBDF_95712  PF00331.20
# 295    chz  NFBJIBDF_96180  PF01915.22
# 296    chz  NFBJIBDF_97416  PF01670.16
# 297    chz  NFBJIBDF_99251   PF12215.8
# 298    chz  NFBJIBDF_99268  PF00722.21
#
#                                            description  bitscore  \
# 294                       Glycosyl hydrolase family 10     170.0
# 295      Glycosyl hydrolase family 3 C-terminal domain     153.9
# 296                       Glycosyl hydrolase family 12      93.6
# 297  beta-glucosidase 2, glycosyl-hydrolase family ...      70.1
# 298                      Glycosyl hydrolases family 16      63.0
#
#            evalue  domains_expected domains_observed
# 294  1.500000e-52               1.0                1
# 295  1.100000e-47               1.2                1
# 296  3.600000e-29               1.0                1
# 297  5.000000e-22               1.0                1
# 298  5.200000e-20               1.4                1

# %%
# ambiguity check: several domain profiles matching the same query?
scan_annotations_concat.groupby('query').apply(len).max()
# Out:
# 3

# %%
# ambiguity check: several domain profiles matching the same query? 
scan_annotations_concat.groupby('query').apply(len) >1
# Out:
# query
# LDFJCBPN_00383    False
# LDFJCBPN_02521    False
# LDFJCBPN_02523    False
# LDFJCBPN_03057    False
# LDFJCBPN_04133    False
# LDFJCBPN_04134    False
# LDFJCBPN_04141    False
# LDFJCBPN_04191    False
# LDFJCBPN_05098    False
# LDFJCBPN_05318    False
# LDFJCBPN_06314    False
# LDFJCBPN_06822    False
# LDFJCBPN_06823    False
# LDFJCBPN_06824    False
# LDFJCBPN_07844    False
# LDFJCBPN_07848    False
# LDFJCBPN_07851    False
# LDFJCBPN_08501    False
# LDFJCBPN_11484    False
# LDFJCBPN_11973    False
# LDFJCBPN_11974    False
# LDFJCBPN_11975    False
# LDFJCBPN_12341    False
# LDFJCBPN_12342    False
# LDFJCBPN_13622    False
# LDFJCBPN_15911    False
# LDFJCBPN_15912    False
# LDFJCBPN_16036    False
# LDFJCBPN_16159    False
# LDFJCBPN_17218    False
# LDFJCBPN_18009    False
# LDFJCBPN_18946    False
# LDFJCBPN_21748    False
# LDFJCBPN_21749    False
# LDFJCBPN_22852    False
# LDFJCBPN_22853    False
# LDFJCBPN_23110    False
# LDFJCBPN_24967    False
# LDFJCBPN_28973    False
# LDFJCBPN_29859    False
# LDFJCBPN_30665    False
# LDFJCBPN_30666    False
# LDFJCBPN_32840    False
# LDFJCBPN_35212    False
# LDFJCBPN_39873    False
# LDFJCBPN_39874    False
# LDFJCBPN_39884    False
# LDFJCBPN_39886    False
# LDFJCBPN_40049    False
# LDFJCBPN_41410     True
# LDFJCBPN_42987    False
# LDFJCBPN_47060    False
# LDFJCBPN_47883     True
# LDFJCBPN_50068    False
# LDFJCBPN_51766    False
# LDFJCBPN_51781    False
# LDFJCBPN_51823    False
# LDFJCBPN_51826    False
# LDFJCBPN_52554    False
# LDFJCBPN_52650    False
# LDFJCBPN_54504    False
# LDFJCBPN_54507    False
# LDFJCBPN_57351    False
# LDFJCBPN_57352    False
# LDFJCBPN_57353    False
# LDFJCBPN_58176    False
# LDFJCBPN_58673    False
# LDFJCBPN_58677    False
# LDFJCBPN_60111    False
# LDFJCBPN_61310    False
# LDFJCBPN_61311    False
# LDFJCBPN_61861    False
# LDFJCBPN_61862    False
# LDFJCBPN_63307     True
# LDFJCBPN_64784    False
# LDFJCBPN_65354    False
# LDFJCBPN_66659    False
# LDFJCBPN_70134    False
# LDFJCBPN_70603    False
# NFBJIBDF_00475    False
# NFBJIBDF_01552    False
# NFBJIBDF_04276    False
# NFBJIBDF_05024    False
# NFBJIBDF_06234    False
# NFBJIBDF_06277    False
# NFBJIBDF_06523    False
# NFBJIBDF_07188     True
# NFBJIBDF_07191     True
# NFBJIBDF_08293    False
# NFBJIBDF_08385    False
# NFBJIBDF_08404    False
# NFBJIBDF_08444    False
# NFBJIBDF_08660    False
# NFBJIBDF_11604    False
# NFBJIBDF_11605    False
# NFBJIBDF_12024    False
# NFBJIBDF_14162    False
# NFBJIBDF_14164    False
# NFBJIBDF_14166    False
# NFBJIBDF_14167    False
# NFBJIBDF_14168    False
# NFBJIBDF_14170    False
# NFBJIBDF_14171     True
# NFBJIBDF_14173    False
# NFBJIBDF_14444    False
# NFBJIBDF_16090    False
# NFBJIBDF_16192    False
# NFBJIBDF_16635     True
# NFBJIBDF_17144    False
# NFBJIBDF_17320    False
# NFBJIBDF_17453    False
# NFBJIBDF_17520     True
# NFBJIBDF_17680    False
# NFBJIBDF_18870    False
# NFBJIBDF_21193    False
# NFBJIBDF_24447    False
# NFBJIBDF_24448    False
# NFBJIBDF_25540    False
# NFBJIBDF_26016    False
# NFBJIBDF_26357     True
# NFBJIBDF_27469    False
# NFBJIBDF_27470    False
# NFBJIBDF_28799    False
# NFBJIBDF_33098    False
# NFBJIBDF_33696    False
# NFBJIBDF_34612    False
# NFBJIBDF_34800    False
# NFBJIBDF_34890    False
# NFBJIBDF_36526    False
# NFBJIBDF_36607    False
# NFBJIBDF_36935    False
# NFBJIBDF_39514     True
# NFBJIBDF_39661    False
# NFBJIBDF_42607    False
# NFBJIBDF_44684     True
# NFBJIBDF_44756     True
# NFBJIBDF_47131    False
# NFBJIBDF_47931    False
# NFBJIBDF_47951    False
# NFBJIBDF_48801    False
# NFBJIBDF_49650    False
# NFBJIBDF_49651    False
# NFBJIBDF_49966    False
# NFBJIBDF_49967    False
# NFBJIBDF_51958    False
# NFBJIBDF_51960    False
# NFBJIBDF_51963    False
# NFBJIBDF_51964    False
# NFBJIBDF_53477    False
# NFBJIBDF_56144    False
# NFBJIBDF_64352    False
# NFBJIBDF_65531    False
# NFBJIBDF_69450    False
# NFBJIBDF_69705    False
# dtype: bool

# %%
scan_annotations_concat
# Out:
#     sample           query       model  \
# 122    chz  NFBJIBDF_18870  PF06964.12
# 134    chz  NFBJIBDF_33696  PF06964.12
# 138    chz  NFBJIBDF_36526  PF06964.12
# 144    chz  NFBJIBDF_42607  PF06964.12
# 155    chz  NFBJIBDF_49966  PF06964.12
# 158    chz  NFBJIBDF_51960  PF06964.12
# 159    chz  NFBJIBDF_51963  PF06964.12
# 162    chz  NFBJIBDF_56144  PF06964.12
# 87     chz  NFBJIBDF_06277  PF00150.18
# 94     chz  NFBJIBDF_08293  PF00150.18
# 97     chz  NFBJIBDF_08444  PF00150.18
# 121    chz  NFBJIBDF_17680  PF00150.18
# 126    chz  NFBJIBDF_25540  PF00150.18
# 152    chz  NFBJIBDF_48801  PF00150.18
# 163    chz  NFBJIBDF_64352  PF00150.18
# 132    chz  NFBJIBDF_28799  PF00331.20
# 137    chz  NFBJIBDF_34890  PF00331.20
# 136    chz  NFBJIBDF_34800  PF02156.15
# 84     chz  NFBJIBDF_04276  PF01915.22
# 92     chz  NFBJIBDF_07191  PF01915.22
# 99     chz  NFBJIBDF_11604  PF01915.22
# 100    chz  NFBJIBDF_11605  PF01915.22
# 104    chz  NFBJIBDF_14166  PF01915.22
# 110    chz  NFBJIBDF_14173  PF01915.22
# 115    chz  NFBJIBDF_16635  PF01915.22
# 120    chz  NFBJIBDF_17520  PF01915.22
# 125    chz  NFBJIBDF_24448  PF01915.22
# 129    chz  NFBJIBDF_26357  PF01915.22
# 130    chz  NFBJIBDF_27469  PF01915.22
# 142    chz  NFBJIBDF_39514  PF01915.22
# 146    chz  NFBJIBDF_44684  PF01915.22
# 148    chz  NFBJIBDF_44756  PF01915.22
# 153    chz  NFBJIBDF_49650  PF01915.22
# 93     chz  NFBJIBDF_07191  PF00933.21
# 98     chz  NFBJIBDF_08660  PF00933.21
# 105    chz  NFBJIBDF_14167  PF00933.21
# 111    chz  NFBJIBDF_14444  PF00933.21
# 112    chz  NFBJIBDF_16090  PF00933.21
# 113    chz  NFBJIBDF_16192  PF00933.21
# 114    chz  NFBJIBDF_16635  PF00933.21
# 116    chz  NFBJIBDF_17144  PF00933.21
# 119    chz  NFBJIBDF_17520  PF00933.21
# 123    chz  NFBJIBDF_21193  PF00933.21
# 124    chz  NFBJIBDF_24447  PF00933.21
# 128    chz  NFBJIBDF_26357  PF00933.21
# 131    chz  NFBJIBDF_27470  PF00933.21
# 139    chz  NFBJIBDF_36607  PF00933.21
# 141    chz  NFBJIBDF_39514  PF00933.21
# 145    chz  NFBJIBDF_44684  PF00933.21
# 147    chz  NFBJIBDF_44756  PF00933.21
# 150    chz  NFBJIBDF_47931  PF00933.21
# 154    chz  NFBJIBDF_49651  PF00933.21
# 90     chz  NFBJIBDF_07188  PF07477.12
# 107    chz  NFBJIBDF_14170  PF07477.12
# 91     chz  NFBJIBDF_07188  PF03648.14
# 109    chz  NFBJIBDF_14171  PF03648.14
# 89     chz  NFBJIBDF_07188  PF07488.12
# 108    chz  NFBJIBDF_14171  PF07488.12
# 166    chz  NFBJIBDF_69705  PF00759.19
# 83     chz  NFBJIBDF_01552  PF00722.21
# 88     chz  NFBJIBDF_06523  PF00722.21
# 95     chz  NFBJIBDF_08385  PF00722.21
# 140    chz  NFBJIBDF_36935  PF00722.21
# 161    chz  NFBJIBDF_53477  PF00722.21
# 165    chz  NFBJIBDF_69450  PF00722.21
# 82     chz  NFBJIBDF_00475  PF01229.17
# 151    chz  NFBJIBDF_47951  PF01229.17
# 96     chz  NFBJIBDF_08404  PF04616.14
# 101    chz  NFBJIBDF_12024  PF04616.14
# 102    chz  NFBJIBDF_14162  PF04616.14
# 103    chz  NFBJIBDF_14164  PF04616.14
# 106    chz  NFBJIBDF_14168  PF04616.14
# 118    chz  NFBJIBDF_17453  PF04616.14
# 127    chz  NFBJIBDF_26016  PF04616.14
# 133    chz  NFBJIBDF_33098  PF04616.14
# 143    chz  NFBJIBDF_39661  PF04616.14
# 156    chz  NFBJIBDF_49967  PF04616.14
# 157    chz  NFBJIBDF_51958  PF04616.14
# 160    chz  NFBJIBDF_51964  PF04616.14
# 164    chz  NFBJIBDF_65531  PF04616.14
# 86     chz  NFBJIBDF_06234  PF01341.17
# 117    chz  NFBJIBDF_17320  PF01341.17
# 135    chz  NFBJIBDF_34612  PF01341.17
# 85     chz  NFBJIBDF_05024  PF01270.17
# 149    chz  NFBJIBDF_47131  PF01270.17
# 15      sp  LDFJCBPN_07848  PF06964.12
# 16      sp  LDFJCBPN_07851  PF06964.12
# 0       sp  LDFJCBPN_00383  PF00150.18
# 6       sp  LDFJCBPN_04141  PF00150.18
# 38      sp  LDFJCBPN_28973  PF00150.18
# 58      sp  LDFJCBPN_51823  PF00150.18
# 61      sp  LDFJCBPN_52650  PF00150.18
# 67      sp  LDFJCBPN_58176  PF00150.18
# 80      sp  LDFJCBPN_70134  PF00150.18
# 77      sp  LDFJCBPN_64784   PF12891.7
# 8       sp  LDFJCBPN_05098  PF00331.20
# 10      sp  LDFJCBPN_06314  PF00331.20
# 17      sp  LDFJCBPN_08501  PF00331.20
# 44      sp  LDFJCBPN_39873  PF00331.20
# 45      sp  LDFJCBPN_39874  PF00331.20
# 65      sp  LDFJCBPN_57352  PF00331.20
# 66      sp  LDFJCBPN_57353  PF00331.20
# 11      sp  LDFJCBPN_06822   PF15979.5
# 12      sp  LDFJCBPN_06823   PF15979.5
# 19      sp  LDFJCBPN_11973   PF15979.5
# 20      sp  LDFJCBPN_11974   PF15979.5
# 21      sp  LDFJCBPN_11975   PF15979.5
# 1       sp  LDFJCBPN_02521  PF01915.22
# 37      sp  LDFJCBPN_24967  PF01915.22
# 46      sp  LDFJCBPN_39884  PF01915.22
# 48      sp  LDFJCBPN_40049  PF01915.22
# 50      sp  LDFJCBPN_41410  PF01915.22
# 53      sp  LDFJCBPN_47883  PF01915.22
# 60      sp  LDFJCBPN_52554  PF01915.22
# 63      sp  LDFJCBPN_54507  PF01915.22
# 72      sp  LDFJCBPN_61311  PF01915.22
# 74      sp  LDFJCBPN_61862  PF01915.22
# 75      sp  LDFJCBPN_63307  PF01915.22
# 2       sp  LDFJCBPN_02523  PF00933.21
# 3       sp  LDFJCBPN_03057  PF00933.21
# 7       sp  LDFJCBPN_04191  PF00933.21
# 31      sp  LDFJCBPN_18946  PF00933.21
# 42      sp  LDFJCBPN_32840  PF00933.21
# 47      sp  LDFJCBPN_39886  PF00933.21
# 49      sp  LDFJCBPN_41410  PF00933.21
# 54      sp  LDFJCBPN_47883  PF00933.21
# 55      sp  LDFJCBPN_50068  PF00933.21
# 56      sp  LDFJCBPN_51766  PF00933.21
# 57      sp  LDFJCBPN_51781  PF00933.21
# 62      sp  LDFJCBPN_54504  PF00933.21
# 64      sp  LDFJCBPN_57351  PF00933.21
# 70      sp  LDFJCBPN_60111  PF00933.21
# 71      sp  LDFJCBPN_61310  PF00933.21
# 73      sp  LDFJCBPN_61861  PF00933.21
# 76      sp  LDFJCBPN_63307  PF00933.21
# 81      sp  LDFJCBPN_70603  PF00933.21
# 33      sp  LDFJCBPN_21749  PF07477.12
# 25      sp  LDFJCBPN_15911  PF07488.12
# 26      sp  LDFJCBPN_15912  PF07488.12
# 32      sp  LDFJCBPN_21748  PF07488.12
# 30      sp  LDFJCBPN_18009  PF00759.19
# 40      sp  LDFJCBPN_30665  PF00759.19
# 41      sp  LDFJCBPN_30666  PF00759.19
# 18      sp  LDFJCBPN_11484  PF00457.17
# 39      sp  LDFJCBPN_29859  PF00457.17
# 78      sp  LDFJCBPN_65354  PF00457.17
# 29      sp  LDFJCBPN_17218  PF00722.21
# 79      sp  LDFJCBPN_66659  PF00722.21
# 9       sp  LDFJCBPN_05318  PF04616.14
# 14      sp  LDFJCBPN_07844  PF04616.14
# 28      sp  LDFJCBPN_16159  PF04616.14
# 51      sp  LDFJCBPN_42987  PF04616.14
# 52      sp  LDFJCBPN_47060  PF04616.14
# 59      sp  LDFJCBPN_51826  PF04616.14
# 4       sp  LDFJCBPN_04133  PF01341.17
# 5       sp  LDFJCBPN_04134  PF01341.17
# 22      sp  LDFJCBPN_12341  PF01341.17
# 23      sp  LDFJCBPN_12342  PF01341.17
# 34      sp  LDFJCBPN_22852  PF01341.17
# 35      sp  LDFJCBPN_22853  PF01341.17
# 68      sp  LDFJCBPN_58673  PF01341.17
# 24      sp  LDFJCBPN_13622  PF01270.17
# 27      sp  LDFJCBPN_16036  PF01270.17
# 36      sp  LDFJCBPN_23110  PF01270.17
# 43      sp  LDFJCBPN_35212  PF01270.17
# 69      sp  LDFJCBPN_58677  PF01270.17
# 13      sp  LDFJCBPN_06824   PF17829.1
#
#                                          description  bitscore         evalue  \
# 122    Alpha-L-arabinofuranosidase C-terminal domain     142.6   1.500000e-44
# 134    Alpha-L-arabinofuranosidase C-terminal domain     139.1   1.900000e-43
# 138    Alpha-L-arabinofuranosidase C-terminal domain      99.0   4.000000e-31
# 144    Alpha-L-arabinofuranosidase C-terminal domain     131.8   3.300000e-41
# 155    Alpha-L-arabinofuranosidase C-terminal domain      98.1   7.500000e-31
# 158    Alpha-L-arabinofuranosidase C-terminal domain     147.9   3.800000e-46
# 159    Alpha-L-arabinofuranosidase C-terminal domain     107.3   1.200000e-33
# 162    Alpha-L-arabinofuranosidase C-terminal domain      96.5   2.300000e-30
# 87           Cellulase (glycosyl hydrolase family 5)     103.5   1.800000e-32
# 94           Cellulase (glycosyl hydrolase family 5)      82.8   3.500000e-26
# 97           Cellulase (glycosyl hydrolase family 5)     117.1   1.200000e-36
# 121          Cellulase (glycosyl hydrolase family 5)     102.3   4.000000e-32
# 126          Cellulase (glycosyl hydrolase family 5)      95.5   4.700000e-30
# 152          Cellulase (glycosyl hydrolase family 5)      76.8   2.300000e-24
# 163          Cellulase (glycosyl hydrolase family 5)     116.5   1.800000e-36
# 132                     Glycosyl hydrolase family 10      95.5   4.200000e-30
# 137                     Glycosyl hydrolase family 10      63.4   2.400000e-20
# 136                     Glycosyl hydrolase family 26     113.4   1.800000e-35
# 84     Glycosyl hydrolase family 3 C-terminal domain      61.8   1.100000e-19
# 92     Glycosyl hydrolase family 3 C-terminal domain     172.3   1.600000e-53
# 99     Glycosyl hydrolase family 3 C-terminal domain      72.7   5.000000e-23
# 100    Glycosyl hydrolase family 3 C-terminal domain     120.0   1.600000e-37
# 104    Glycosyl hydrolase family 3 C-terminal domain     133.2   1.400000e-41
# 110    Glycosyl hydrolase family 3 C-terminal domain      75.9   5.200000e-24
# 115    Glycosyl hydrolase family 3 C-terminal domain     217.0   3.100000e-67
# 120    Glycosyl hydrolase family 3 C-terminal domain     175.6   1.600000e-54
# 125    Glycosyl hydrolase family 3 C-terminal domain     136.0   2.100000e-42
# 129    Glycosyl hydrolase family 3 C-terminal domain     120.5   1.200000e-37
# 130    Glycosyl hydrolase family 3 C-terminal domain     156.6   1.000000e-48
# 142    Glycosyl hydrolase family 3 C-terminal domain     208.4   1.400000e-64
# 146    Glycosyl hydrolase family 3 C-terminal domain     181.6   2.300000e-56
# 148    Glycosyl hydrolase family 3 C-terminal domain     181.6   2.300000e-56
# 153    Glycosyl hydrolase family 3 C-terminal domain     105.9   3.400000e-33
# 93     Glycosyl hydrolase family 3 N terminal domain     165.3   2.800000e-51
# 98     Glycosyl hydrolase family 3 N terminal domain      78.2   9.200000e-25
# 105    Glycosyl hydrolase family 3 N terminal domain     172.3   2.100000e-53
# 111    Glycosyl hydrolase family 3 N terminal domain      97.9   8.900000e-31
# 112    Glycosyl hydrolase family 3 N terminal domain     161.9   3.100000e-50
# 113    Glycosyl hydrolase family 3 N terminal domain     152.4   2.400000e-47
# 114    Glycosyl hydrolase family 3 N terminal domain     258.1   1.600000e-79
# 116    Glycosyl hydrolase family 3 N terminal domain      67.1   2.200000e-21
# 119    Glycosyl hydrolase family 3 N terminal domain     247.5   2.600000e-76
# 123    Glycosyl hydrolase family 3 N terminal domain     287.5   1.800000e-88
# 124    Glycosyl hydrolase family 3 N terminal domain     248.3   1.500000e-76
# 128    Glycosyl hydrolase family 3 N terminal domain     141.8   3.800000e-44
# 131    Glycosyl hydrolase family 3 N terminal domain     145.3   3.500000e-45
# 139    Glycosyl hydrolase family 3 N terminal domain     161.9   3.100000e-50
# 141    Glycosyl hydrolase family 3 N terminal domain     214.7   2.500000e-66
# 145    Glycosyl hydrolase family 3 N terminal domain     232.6   9.400000e-72
# 147    Glycosyl hydrolase family 3 N terminal domain     232.6   9.400000e-72
# 150    Glycosyl hydrolase family 3 N terminal domain     106.0   3.200000e-33
# 154    Glycosyl hydrolase family 3 N terminal domain     168.4   3.200000e-52
# 90           Glycosyl hydrolase family 67 C-terminus     312.9   1.400000e-96
# 107          Glycosyl hydrolase family 67 C-terminus     311.3   4.200000e-96
# 91           Glycosyl hydrolase family 67 N-terminus      69.6   3.600000e-22
# 109          Glycosyl hydrolase family 67 N-terminus      88.6   4.500000e-28
# 89        Glycosyl hydrolase family 67 middle domain     513.8  2.200000e-157
# 108       Glycosyl hydrolase family 67 middle domain     277.1   2.200000e-85
# 166                      Glycosyl hydrolase family 9     223.9   6.000000e-69
# 83                     Glycosyl hydrolases family 16     107.6   6.100000e-34
# 88                     Glycosyl hydrolases family 16      62.3   5.000000e-20
# 95                     Glycosyl hydrolases family 16     109.8   1.300000e-34
# 140                    Glycosyl hydrolases family 16      87.5   9.000000e-28
# 161                    Glycosyl hydrolases family 16      70.5   1.500000e-22
# 165                    Glycosyl hydrolases family 16      67.7   1.100000e-21
# 82                     Glycosyl hydrolases family 39     154.9   3.500000e-48
# 151                    Glycosyl hydrolases family 39     122.4   2.500000e-38
# 96                     Glycosyl hydrolases family 43      79.1   4.400000e-25
# 101                    Glycosyl hydrolases family 43     123.4   1.400000e-38
# 102                    Glycosyl hydrolases family 43     103.1   2.200000e-32
# 103                    Glycosyl hydrolases family 43      92.8   3.000000e-29
# 106                    Glycosyl hydrolases family 43     321.1   7.700000e-99
# 118                    Glycosyl hydrolases family 43     146.6   1.200000e-45
# 127                    Glycosyl hydrolases family 43     145.8   2.000000e-45
# 133                    Glycosyl hydrolases family 43     194.2   3.700000e-60
# 143                    Glycosyl hydrolases family 43     101.7   5.600000e-32
# 156                    Glycosyl hydrolases family 43     129.3   2.200000e-40
# 157                    Glycosyl hydrolases family 43     107.8   7.700000e-34
# 160                    Glycosyl hydrolases family 43     189.9   7.400000e-59
# 164                    Glycosyl hydrolases family 43     140.5   8.500000e-44
# 86                      Glycosyl hydrolases family 6      97.6   1.400000e-30
# 117                     Glycosyl hydrolases family 6     117.7   1.100000e-36
# 135                     Glycosyl hydrolases family 6     137.8   7.800000e-43
# 85                      Glycosyl hydrolases family 8      63.7   1.600000e-20
# 149                     Glycosyl hydrolases family 8     212.7   8.000000e-66
# 15     Alpha-L-arabinofuranosidase C-terminal domain      96.5   2.300000e-30
# 16     Alpha-L-arabinofuranosidase C-terminal domain      95.5   4.800000e-30
# 0            Cellulase (glycosyl hydrolase family 5)     153.7   8.300000e-48
# 6            Cellulase (glycosyl hydrolase family 5)     110.4   1.400000e-34
# 38           Cellulase (glycosyl hydrolase family 5)      77.0   2.100000e-24
# 58           Cellulase (glycosyl hydrolase family 5)      72.8   4.000000e-23
# 61           Cellulase (glycosyl hydrolase family 5)      69.5   4.000000e-22
# 67           Cellulase (glycosyl hydrolase family 5)     202.4   1.200000e-62
# 80           Cellulase (glycosyl hydrolase family 5)     113.3   1.700000e-35
# 77                     Glycoside hydrolase family 44      79.2   5.500000e-25
# 8                       Glycosyl hydrolase family 10     189.3   1.200000e-58
# 10                      Glycosyl hydrolase family 10     150.0   1.100000e-46
# 17                      Glycosyl hydrolase family 10     267.7   1.700000e-82
# 44                      Glycosyl hydrolase family 10      90.3   1.600000e-28
# 45                      Glycosyl hydrolase family 10      76.4   2.600000e-24
# 65                      Glycosyl hydrolase family 10      67.1   1.800000e-21
# 66                      Glycosyl hydrolase family 10      82.3   4.400000e-26
# 11                     Glycosyl hydrolase family 115     299.2   5.800000e-92
# 12                     Glycosyl hydrolase family 115      61.9   8.900000e-20
# 19                     Glycosyl hydrolase family 115     165.6   2.600000e-51
# 20                     Glycosyl hydrolase family 115     112.8   2.900000e-35
# 21                     Glycosyl hydrolase family 115      78.9   5.800000e-25
# 1      Glycosyl hydrolase family 3 C-terminal domain      80.1   2.700000e-25
# 37     Glycosyl hydrolase family 3 C-terminal domain      81.5   9.900000e-26
# 46     Glycosyl hydrolase family 3 C-terminal domain      70.2   3.000000e-22
# 48     Glycosyl hydrolase family 3 C-terminal domain      79.0   5.900000e-25
# 50     Glycosyl hydrolase family 3 C-terminal domain     194.7   2.200000e-60
# 53     Glycosyl hydrolase family 3 C-terminal domain     123.1   1.900000e-38
# 60     Glycosyl hydrolase family 3 C-terminal domain     120.5   1.100000e-37
# 63     Glycosyl hydrolase family 3 C-terminal domain     143.3   1.200000e-44
# 72     Glycosyl hydrolase family 3 C-terminal domain      62.4   7.200000e-20
# 74     Glycosyl hydrolase family 3 C-terminal domain      90.7   1.600000e-28
# 75     Glycosyl hydrolase family 3 C-terminal domain     185.1   1.800000e-57
# 2      Glycosyl hydrolase family 3 N terminal domain     179.6   1.300000e-55
# 3      Glycosyl hydrolase family 3 N terminal domain      91.7   7.100000e-29
# 7      Glycosyl hydrolase family 3 N terminal domain      62.3   6.300000e-20
# 31     Glycosyl hydrolase family 3 N terminal domain      98.6   5.500000e-31
# 42     Glycosyl hydrolase family 3 N terminal domain      90.9   1.200000e-28
# 47     Glycosyl hydrolase family 3 N terminal domain     121.0   8.300000e-38
# 49     Glycosyl hydrolase family 3 N terminal domain     245.2   1.300000e-75
# 54     Glycosyl hydrolase family 3 N terminal domain      96.6   2.300000e-30
# 55     Glycosyl hydrolase family 3 N terminal domain     133.8   1.000000e-41
# 56     Glycosyl hydrolase family 3 N terminal domain     270.5   2.600000e-83
# 57     Glycosyl hydrolase family 3 N terminal domain      65.5   6.600000e-21
# 62     Glycosyl hydrolase family 3 N terminal domain      92.1   5.300000e-29
# 64     Glycosyl hydrolase family 3 N terminal domain      87.6   1.200000e-27
# 70     Glycosyl hydrolase family 3 N terminal domain      62.7   4.800000e-20
# 71     Glycosyl hydrolase family 3 N terminal domain      60.5   2.100000e-19
# 73     Glycosyl hydrolase family 3 N terminal domain     163.8   7.700000e-51
# 76     Glycosyl hydrolase family 3 N terminal domain     147.4   7.600000e-46
# 81     Glycosyl hydrolase family 3 N terminal domain      69.4   4.300000e-22
# 33           Glycosyl hydrolase family 67 C-terminus      69.1   5.100000e-22
# 25        Glycosyl hydrolase family 67 middle domain     125.3   3.400000e-39
# 26        Glycosyl hydrolase family 67 middle domain      61.7   7.600000e-20
# 32        Glycosyl hydrolase family 67 middle domain     211.1   2.700000e-65
# 30                       Glycosyl hydrolase family 9     366.0  4.500000e-112
# 40                       Glycosyl hydrolase family 9      86.6   2.900000e-27
# 41                       Glycosyl hydrolase family 9      73.3   3.300000e-23
# 18                     Glycosyl hydrolases family 11      67.4   1.500000e-21
# 39                     Glycosyl hydrolases family 11     153.1   7.400000e-48
# 78                     Glycosyl hydrolases family 11     102.3   3.000000e-32
# 29                     Glycosyl hydrolases family 16     105.3   3.100000e-33
# 79                     Glycosyl hydrolases family 16      60.9   1.300000e-19
# 9                      Glycosyl hydrolases family 43      76.8   2.200000e-24
# 14                     Glycosyl hydrolases family 43      71.2   1.200000e-22
# 28                     Glycosyl hydrolases family 43     155.8   1.800000e-48
# 51                     Glycosyl hydrolases family 43      68.6   6.700000e-22
# 52                     Glycosyl hydrolases family 43      67.0   2.100000e-21
# 59                     Glycosyl hydrolases family 43      68.4   7.900000e-22
# 4                       Glycosyl hydrolases family 6      86.1   4.500000e-27
# 5                       Glycosyl hydrolases family 6      82.3   6.300000e-26
# 22                      Glycosyl hydrolases family 6      90.6   1.900000e-28
# 23                      Glycosyl hydrolases family 6     133.0   2.400000e-41
# 34                      Glycosyl hydrolases family 6      59.8   4.400000e-19
# 35                      Glycosyl hydrolases family 6     110.5   1.600000e-34
# 68                      Glycosyl hydrolases family 6      65.6   7.700000e-21
# 24                      Glycosyl hydrolases family 8     180.2   6.200000e-56
# 27                      Glycosyl hydrolases family 8      77.8   8.400000e-25
# 36                      Glycosyl hydrolases family 8      58.6   5.600000e-19
# 43                      Glycosyl hydrolases family 8      58.1   8.300000e-19
# 69                      Glycosyl hydrolases family 8      76.0   2.900000e-24
# 13   Gylcosyl hydrolase family 115 C-terminal domain     192.3   7.500000e-60
#
#      domains_expected domains_observed
# 122               1.3                1
# 134               1.8                2
# 138               1.4                1
# 144               1.2                1
# 155               1.0                1
# 158               1.0                1
# 159               1.0                1
# 162               1.2                1
# 87                1.1                1
# 94                1.1                1
# 97                2.2                2
# 121               1.2                1
# 126               1.3                1
# 152               1.0                1
# 163               2.0                2
# 132               1.0                1
# 137               1.0                1
# 136               1.3                1
# 84                1.1                1
# 92                1.4                1
# 99                1.1                1
# 100               1.0                1
# 104               1.1                1
# 110               1.2                1
# 115               1.3                1
# 120               1.3                1
# 125               1.1                1
# 129               1.3                1
# 130               1.4                1
# 142               1.3                1
# 146               1.2                1
# 148               1.2                1
# 153               1.2                1
# 93                1.7                1
# 98                1.0                1
# 105               1.8                1
# 111               1.1                1
# 112               1.0                1
# 113               1.0                1
# 114               1.3                1
# 116               2.1                2
# 119               1.2                1
# 123               1.3                1
# 124               1.1                1
# 128               1.1                1
# 131               1.7                2
# 139               1.0                1
# 141               1.1                1
# 145               1.1                1
# 147               1.1                1
# 150               1.0                1
# 154               1.0                1
# 90                1.5                1
# 107               1.1                1
# 91                1.4                1
# 109               1.2                1
# 89                1.1                1
# 108               1.1                1
# 166               1.3                1
# 83                1.4                1
# 88                1.5                2
# 95                1.1                1
# 140               1.3                1
# 161               1.0                1
# 165               1.3                1
# 82                1.2                1
# 151               1.3                1
# 96                1.0                1
# 101               1.0                1
# 102               1.0                1
# 103               2.4                1
# 106               1.2                1
# 118               1.6                1
# 127               1.1                1
# 133               1.0                1
# 143               1.9                1
# 156               1.2                1
# 157               1.7                1
# 160               1.0                1
# 164               1.3                1
# 86                1.0                1
# 117               1.0                1
# 135               2.1                2
# 85                1.1                1
# 149               1.1                1
# 15                1.1                1
# 16                1.1                1
# 0                 1.0                1
# 6                 1.0                1
# 38                1.1                1
# 58                1.2                1
# 61                2.2                2
# 67                1.3                1
# 80                1.4                1
# 77                1.1                1
# 8                 1.0                1
# 10                1.2                1
# 17                1.0                1
# 44                1.0                1
# 45                1.0                1
# 65                1.0                1
# 66                1.0                1
# 11                1.1                1
# 12                1.5                1
# 19                1.0                1
# 20                1.0                1
# 21                1.1                1
# 1                 1.1                1
# 37                1.1                1
# 46                1.1                1
# 48                1.3                1
# 50                1.5                1
# 53                1.2                1
# 60                1.2                1
# 63                1.1                1
# 72                1.6                2
# 74                1.0                1
# 75                1.4                1
# 2                 1.0                1
# 3                 1.0                1
# 7                 1.0                1
# 31                1.1                1
# 42                1.0                1
# 47                1.0                1
# 49                1.2                1
# 54                1.2                1
# 55                2.0                2
# 56                1.0                1
# 57                1.1                1
# 62                1.1                1
# 64                1.3                1
# 70                1.1                1
# 71                1.1                1
# 73                1.5                2
# 76                1.4                1
# 81                1.0                1
# 33                2.1                2
# 25                1.0                1
# 26                1.1                1
# 32                1.0                1
# 30                1.3                1
# 40                1.1                1
# 41                1.6                2
# 18                1.0                1
# 39                1.1                1
# 78                2.1                1
# 29                1.3                1
# 79                1.2                1
# 9                 1.3                1
# 14                1.1                1
# 28                1.1                1
# 51                2.1                2
# 52                1.1                1
# 59                1.0                1
# 4                 1.0                1
# 5                 1.1                1
# 22                1.0                1
# 23                1.0                1
# 34                1.0                1
# 35                1.0                1
# 68                1.0                1
# 24                1.0                1
# 27                1.2                1
# 36                1.1                1
# 43                1.1                1
# 69                1.1                1
# 13                1.3                1

# %%
# there are some duplicates

# %%
len(scan_annotations_concat)
# Out:
# 167

# %%
# sorting by first name 
#scan_annotations_concat.sort_values("query", inplace = True) 
  
# dropping ALL duplicte values 
#scan_annotations_concat.drop_duplicates(subset ="query", 
#                     keep = False, inplace = True)

# %%
# we have removed the duplicates

# %%
os.makedirs('glyco', exist_ok=True)

# %%
# export domain annotations
scan_annotations_concat.to_csv('glyco/annotations.tsv', sep='\t', index=False)

# %% [markdown]
# Extract nucleotide (or protein) sequences with positive matches

# %%
scan_annotations_concat['description'].value_counts()
# Out:
# Glycosyl hydrolase family 3 N terminal domain      37
# Glycosyl hydrolase family 3 C-terminal domain      26
# Glycosyl hydrolases family 43                      19
# Cellulase (glycosyl hydrolase family 5)            14
# Alpha-L-arabinofuranosidase C-terminal domain      10
# Glycosyl hydrolases family 6                       10
# Glycosyl hydrolase family 10                        9
# Glycosyl hydrolases family 16                       8
# Glycosyl hydrolases family 8                        7
# Glycosyl hydrolase family 67 middle domain          5
# Glycosyl hydrolase family 115                       5
# Glycosyl hydrolase family 9                         4
# Glycosyl hydrolases family 11                       3
# Glycosyl hydrolase family 67 C-terminus             3
# Glycosyl hydrolase family 67 N-terminus             2
# Glycosyl hydrolases family 39                       2
# Gylcosyl hydrolase family 115 C-terminal domain     1
# Glycosyl hydrolase family 26                        1
# Glycoside hydrolase family 44                       1
# Name: description, dtype: int64

# %%
selected_queries = set(scan_annotations_concat['query'])
proteins = [
    SeqIO.parse('annotation/sp/sp_assembly.fasta.ffn', 'fasta'),
    SeqIO.parse('annotation/chz/chz_assembly.fasta.ffn', 'fasta')
]
for samp, prots in zip(samples, proteins):
    SeqIO.write((seq for seq in prots if seq.id in selected_queries), f'glyco/{samp}.faa', 'fasta')
